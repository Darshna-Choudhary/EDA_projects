# %% [markdown]
# If this is for a college project or resume:
# 1. Build a dashboard showing real-time pollution status by city.
# 2. Identify top 10 most polluted stations.
# 3. Compare pollution patterns across pollutants.
# 4. Create a pollution risk index per city.

# %% [markdown]
# 1. Power bi
# 2. line graph ✅
# 3. stack plot ✅
# 4. histogram ✅
